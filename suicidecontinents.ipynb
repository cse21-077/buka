# %%
import pandas as pd

# Define a dictionary mapping each country to its corresponding continent
continent_mapping = {
    'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
    'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
    'Bahrain': 'Asia', 'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe',
    'Belize': 'North America', 'Bosnia and Herzegovina': 'Europe', 'Brazil': 'South America',
    'Bulgaria': 'Europe', 'Canada': 'North America', 'Chile': 'South America', 'Colombia': 'South America',
    'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cuba': 'North America', 'Cyprus': 'Asia',
    'Czech Republic': 'Europe', 'Denmark': 'Europe', 'Ecuador': 'South America', 'El Salvador': 'North America',
    'Estonia': 'Europe', 'Fiji': 'Australia', 'Finland': 'Europe', 'France': 'Europe', 'Georgia': 'Asia',
    'Germany': 'Europe', 'Greece': 'Europe', 'Grenada': 'North America', 'Guatemala': 'North America',
    'Guyana': 'South America', 'Hungary': 'Europe', 'Iceland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe',
    'Jamaica': 'North America', 'Japan': 'Asia', 'Kazakhstan': 'Asia', 'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia', 'Latvia': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe',
    'Maldives': 'Asia', 'Malta': 'Europe', 'Mauritius': 'Africa', 'Mexico': 'North America',
    'Montenegro': 'Europe', 'Netherlands': 'Europe', 'New Zealand': 'Australia', 'Nicaragua': 'North America',
    'Norway': 'Europe', 'Oman': 'Asia', 'Panama': 'North America', 'Paraguay': 'South America',
    'Philippines': 'Asia', 'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Republic of Ireland': 'Europe',
    'Romania': 'Europe', 'Saint Lucia': 'North America', 'Saint Vincent and the Grenadines': 'North America',
    'Serbia': 'Europe', 'Seychelles': 'Africa', 'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe',
    'South Africa': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia', 'Suriname': 'South America',
    'Sweden': 'Europe', 'Switzerland': 'Europe', 'Thailand': 'Asia', 'The Bahamas': 'North America',
    'Trinidad and Tobago': 'North America', 'Turkmenistan': 'Asia', 'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia', 'United Kingdom': 'Europe', 'United States': 'North America',
    'Uruguay': 'South America', 'Uzbekistan': 'Asia'
}

# Read the Excel file
df = pd.read_excel('master1.xlsx')

# Add a new column 'Continent' based on the mapping
df['Continent'] = df['country'].map(continent_mapping)

# Group by 'Continent' and aggregate the data
grouped_df = df.groupby(['Continent', 'year', 'sex', 'age'])[['suicide_no', 'population', 'suicides/100k pop', 'gdp_for_year ($)', 'gdp_per_capita ($)', 'generation']].sum().reset_index()

# Output the grouped data to a new Excel file
grouped_df.to_excel('grouped_cabana.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 34
#      31 df = pd.read_excel('master1.xlsx')
#      33 # Add a new column 'Continent' based on the mapping
# ---> 34 df['Continent'] = df['country'].map(continent_mapping)
#      36 # Group by 'Continent' and aggregate the data
#      37 grouped_df = df.groupby(['Continent', 'year', 'sex', 'age'])[['suicide_no', 'population', 'suicides/100k pop', 'gdp_for_year ($)', 'gdp_per_capita ($)', 'generation']].sum().reset_index()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# ...

# %%
import pandas as pd

# Define a dictionary mapping each country to its corresponding continent
continent_mapping = {
    'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
    'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
    'Bahrain': 'Asia', 'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe',
    'Belize': 'North America', 'Bosnia and Herzegovina': 'Europe', 'Brazil': 'South America',
    'Bulgaria': 'Europe', 'Canada': 'North America', 'Chile': 'South America', 'Colombia': 'South America',
    'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cuba': 'North America', 'Cyprus': 'Asia',
    'Czech Republic': 'Europe', 'Denmark': 'Europe', 'Ecuador': 'South America', 'El Salvador': 'North America',
    'Estonia': 'Europe', 'Fiji': 'Australia', 'Finland': 'Europe', 'France': 'Europe', 'Georgia': 'Asia',
    'Germany': 'Europe', 'Greece': 'Europe', 'Grenada': 'North America', 'Guatemala': 'North America',
    'Guyana': 'South America', 'Hungary': 'Europe', 'Iceland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe',
    'Jamaica': 'North America', 'Japan': 'Asia', 'Kazakhstan': 'Asia', 'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia', 'Latvia': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe',
    'Maldives': 'Asia', 'Malta': 'Europe', 'Mauritius': 'Africa', 'Mexico': 'North America',
    'Montenegro': 'Europe', 'Netherlands': 'Europe', 'New Zealand': 'Australia', 'Nicaragua': 'North America',
    'Norway': 'Europe', 'Oman': 'Asia', 'Panama': 'North America', 'Paraguay': 'South America',
    'Philippines': 'Asia', 'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Republic of Ireland': 'Europe',
    'Romania': 'Europe', 'Saint Lucia': 'North America', 'Saint Vincent and the Grenadines': 'North America',
    'Serbia': 'Europe', 'Seychelles': 'Africa', 'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe',
    'South Africa': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia', 'Suriname': 'South America',
    'Sweden': 'Europe', 'Switzerland': 'Europe', 'Thailand': 'Asia', 'The Bahamas': 'North America',
    'Trinidad and Tobago': 'North America', 'Turkmenistan': 'Asia', 'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia', 'United Kingdom': 'Europe', 'United States': 'North America',
    'Uruguay': 'South America', 'Uzbekistan': 'Asia'
}

# Read the Excel file
df = pd.read_excel('master1.xlsx')

# Display available columns
print("Prev columns:")
for col in df.columns:
    print(col)
# Add a new column 'Continent' based on the mapping
df['Continent'] = df['country'].map(continent_mapping)

# Group by 'Continent' and aggregate the data
grouped_df = df.groupby(['Continent', 'year', 'sex', 'age'])[['suicide_no', 'population', 'suicides/100k pop', 'gdp_for_year ($)', 'gdp_per_capita ($)', 'generation']].sum().reset_index()

# Output the grouped data to a new Excel file
grouped_df.to_excel('grouped_cabana.xlsx', index=False)
# Out:
# Prev columns:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 38
#      36     print(col)
#      37 # Add a new column 'Continent' based on the mapping
# ---> 38 df['Continent'] = df['country'].map(continent_mapping)
#      40 # Group by 'Continent' and aggregate the data
#      41 grouped_df = df.groupby(['Continent', 'year', 'sex', 'age'])[['suicide_no', 'population', 'suicides/100k pop', 'gdp_for_year ($)', 'gdp_per_capita ($)', 'generation']].sum().reset_index()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# ...

# %%
import pandas as pd
# Specify the sheet name
sheet_name = 'master'
# Read the Excel file with the specified sheet name
df = pd.read_excel('master1.xlsx', sheet_name=sheet_name)
# Define a dictionary mapping each country to its corresponding continent
continent_mapping = {
    'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
    'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
    'Bahrain': 'Asia', 'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe',
    'Belize': 'North America', 'Bosnia and Herzegovina': 'Europe', 'Brazil': 'South America',
    'Bulgaria': 'Europe', 'Canada': 'North America', 'Chile': 'South America', 'Colombia': 'South America',
    'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cuba': 'North America', 'Cyprus': 'Asia',
    'Czech Republic': 'Europe', 'Denmark': 'Europe', 'Ecuador': 'South America', 'El Salvador': 'North America',
    'Estonia': 'Europe', 'Fiji': 'Australia', 'Finland': 'Europe', 'France': 'Europe', 'Georgia': 'Asia',
    'Germany': 'Europe', 'Greece': 'Europe', 'Grenada': 'North America', 'Guatemala': 'North America',
    'Guyana': 'South America', 'Hungary': 'Europe', 'Iceland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe',
    'Jamaica': 'North America', 'Japan': 'Asia', 'Kazakhstan': 'Asia', 'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia', 'Latvia': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe',
    'Maldives': 'Asia', 'Malta': 'Europe', 'Mauritius': 'Africa', 'Mexico': 'North America',
    'Montenegro': 'Europe', 'Netherlands': 'Europe', 'New Zealand': 'Australia', 'Nicaragua': 'North America',
    'Norway': 'Europe', 'Oman': 'Asia', 'Panama': 'North America', 'Paraguay': 'South America',
    'Philippines': 'Asia', 'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Republic of Ireland': 'Europe',
    'Romania': 'Europe', 'Saint Lucia': 'North America', 'Saint Vincent and the Grenadines': 'North America',
    'Serbia': 'Europe', 'Seychelles': 'Africa', 'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe',
    'South Africa': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia', 'Suriname': 'South America',
    'Sweden': 'Europe', 'Switzerland': 'Europe', 'Thailand': 'Asia', 'The Bahamas': 'North America',
    'Trinidad and Tobago': 'North America', 'Turkmenistan': 'Asia', 'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia', 'United Kingdom': 'Europe', 'United States': 'North America',
    'Uruguay': 'South America', 'Uzbekistan': 'Asia'
}

# Add a new column 'Continent' based on the mapping
df['Continent'] = df['Country'].map(continent_mapping)

# Group by 'Continent' and aggregate the data
grouped_df = df.groupby(['Continent', 'year', 'sex', 'age'])[['suicides_no', 'population', 'suicides/100k pop', ' gdp_for_year ($)', 'gdp_per_capita ($)', 'generation']].sum().reset_index()

# Output the grouped data to a new Excel file
grouped_df.to_excel('grouped_master.xlsx', index=False)
# Out:
# Available columns:
# Country
# year
# sex
# age
# suicides_no
# population
# suicides/100k pop
# country-year
# HDI for year
#  gdp_for_year ($)
# gdp_per_capita ($)
# generation
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 45
#      42 df['Continent'] = df['Country'].map(continent_mapping)
#      44 # Group by 'Continent' and aggregate the data
# ---> 45 grouped_df = df.groupby(['Continent', 'year', 'sex', 'age'])[['suicides_no', 'population', 'suicides/100k pop', ' gdp_for_year ($)', 'gdp_per_capita ($)', 'generation']].sum().reset_index()
#      47 # Output the grouped data to a new Excel file
#      48 grouped_df.to_excel('grouped_master.xlsx', index=False)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1964, in DataFrameGroupBy.__getitem__(self, key)
#    1957 if isinstance(key, tuple) and len(key) > 1:
# ...

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('master1.xlsx')

# Define a dictionary mapping each country to its corresponding continent
continent_mapping = {
    'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
    'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
    'Bahrain': 'Asia', 'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe',
    'Belize': 'North America', 'Bosnia and Herzegovina': 'Europe', 'Brazil': 'South America',
    'Bulgaria': 'Europe', 'Canada': 'North America', 'Chile': 'South America', 'Colombia': 'South America',
    'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cuba': 'North America', 'Cyprus': 'Asia',
    'Czech Republic': 'Europe', 'Denmark': 'Europe', 'Ecuador': 'South America', 'El Salvador': 'North America',
    'Estonia': 'Europe', 'Fiji': 'Australia', 'Finland': 'Europe', 'France': 'Europe', 'Georgia': 'Asia',
    'Germany': 'Europe', 'Greece': 'Europe', 'Grenada': 'North America', 'Guatemala': 'North America',
    'Guyana': 'South America', 'Hungary': 'Europe', 'Iceland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe',
    'Jamaica': 'North America', 'Japan': 'Asia', 'Kazakhstan': 'Asia', 'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia', 'Latvia': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe',
    'Maldives': 'Asia', 'Malta': 'Europe', 'Mauritius': 'Africa', 'Mexico': 'North America',
    'Montenegro': 'Europe', 'Netherlands': 'Europe', 'New Zealand': 'Australia', 'Nicaragua': 'North America',
    'Norway': 'Europe', 'Oman': 'Asia', 'Panama': 'North America', 'Paraguay': 'South America',
    'Philippines': 'Asia', 'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Republic of Ireland': 'Europe',
    'Romania': 'Europe', 'Saint Lucia': 'North America', 'Saint Vincent and the Grenadines': 'North America',
    'Serbia': 'Europe', 'Seychelles': 'Africa', 'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe',
    'South Africa': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia', 'Suriname': 'South America',
    'Sweden': 'Europe', 'Switzerland': 'Europe', 'Thailand': 'Asia', 'The Bahamas': 'North America',
    'Trinidad and Tobago': 'North America', 'Turkmenistan': 'Asia', 'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia', 'United Kingdom': 'Europe', 'United States': 'North America',
    'Uruguay': 'South America', 'Uzbekistan': 'Asia'
}

# Add a new column 'Continent' based on the mapping
df['Continent'] = df['Country'].map(continent_mapping)

# Group by 'Continent' and aggregate the data
grouped_df = df.groupby(['Continent', 'year', 'sex', 'age']).agg({
    'suicides_no': 'sum',
    'population': 'sum',
    'suicides/100k pop': 'mean',
    'HDI for year': 'mean',
    ' gdp_for_year ($) ': 'sum',
    'gdp_per_capita ($)': 'mean'
}).reset_index()

# Output the grouped data to a new Excel file
grouped_df.to_excel('grouped_cabana.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 34
#       7 continent_mapping = {
#       8     'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
#       9     'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
#    (...)
#      30     'Uruguay': 'South America', 'Uzbekistan': 'Asia'
#      31 }
#      33 # Add a new column 'Continent' based on the mapping
# ---> 34 df['Continent'] = df['Country'].map(continent_mapping)
#      36 # Group by 'Continent' and aggregate the data
#      37 grouped_df = df.groupby(['Continent', 'year', 'sex', 'age']).agg({
#      38     'suicides_no': 'sum',
#      39     'population': 'sum',
#    (...)
#      43     'gdp_per_capita ($)': 'mean'
#      44 }).reset_index()
#
# ...

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('master1.xlsx')

# Define a dictionary mapping each country to its corresponding continent
continent_mapping = {
    'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
    'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
    'Bahrain': 'Asia', 'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe',
    'Belize': 'North America', 'Bosnia and Herzegovina': 'Europe', 'Brazil': 'South America',
    'Bulgaria': 'Europe', 'Canada': 'North America', 'Chile': 'South America', 'Colombia': 'South America',
    'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cuba': 'North America', 'Cyprus': 'Asia',
    'Czech Republic': 'Europe', 'Denmark': 'Europe', 'Ecuador': 'South America', 'El Salvador': 'North America',
    'Estonia': 'Europe', 'Fiji': 'Australia', 'Finland': 'Europe', 'France': 'Europe', 'Georgia': 'Asia',
    'Germany': 'Europe', 'Greece': 'Europe', 'Grenada': 'North America', 'Guatemala': 'North America',
    'Guyana': 'South America', 'Hungary': 'Europe', 'Iceland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe',
    'Jamaica': 'North America', 'Japan': 'Asia', 'Kazakhstan': 'Asia', 'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia', 'Latvia': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe',
    'Maldives': 'Asia', 'Malta': 'Europe', 'Mauritius': 'Africa', 'Mexico': 'North America',
    'Montenegro': 'Europe', 'Netherlands': 'Europe', 'New Zealand': 'Australia', 'Nicaragua': 'North America',
    'Norway': 'Europe', 'Oman': 'Asia', 'Panama': 'North America', 'Paraguay': 'South America',
    'Philippines': 'Asia', 'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Republic of Ireland': 'Europe',
    'Romania': 'Europe', 'Saint Lucia': 'North America', 'Saint Vincent and the Grenadines': 'North America',
    'Serbia': 'Europe', 'Seychelles': 'Africa', 'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe',
    'South Africa': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia', 'Suriname': 'South America',
    'Sweden': 'Europe', 'Switzerland': 'Europe', 'Thailand': 'Asia', 'The Bahamas': 'North America',
    'Trinidad and Tobago': 'North America', 'Turkmenistan': 'Asia', 'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia', 'United Kingdom': 'Europe', 'United States': 'North America',
    'Uruguay': 'South America', 'Uzbekistan': 'Asia'
}

# Add a new column 'Continent' based on the mapping
df['Continent'] = df['Country'].map(continent_mapping)

# Group by 'Continent' and aggregate the data
grouped_df = df.groupby(['Continent', 'year', 'sex', 'age']).agg({
    'suicides_no': 'sum',
    'population': 'sum',
    'suicides/100k pop': 'mean',
    'HDI for year': 'mean',
    ' gdp_for_year ($) ': 'sum',
    'gdp_per_capita ($)': 'mean'
}).reset_index()

# Output the grouped data to a new Excel file
grouped_df.to_excel('grouped_cabana.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 34
#       7 continent_mapping = {
#       8     'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
#       9     'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
#    (...)
#      30     'Uruguay': 'South America', 'Uzbekistan': 'Asia'
#      31 }
#      33 # Add a new column 'Continent' based on the mapping
# ---> 34 df['Continent'] = df['Country'].map(continent_mapping)
#      36 # Group by 'Continent' and aggregate the data
#      37 grouped_df = df.groupby(['Continent', 'year', 'sex', 'age']).agg({
#      38     'suicides_no': 'sum',
#      39     'population': 'sum',
#    (...)
#      43     'gdp_per_capita ($)': 'mean'
#      44 }).reset_index()
#
# ...

# %%
import pandas as pd

# Specify the sheet name
sheet_name = 'master'

# Read the Excel file with the specified sheet name
df = pd.read_excel('master1.xlsx', sheet_name=sheet_name)

# Display available columns
print("Available columns:")
for col in df.columns:
    print(col)
# Out:
# Available columns:
# Country
# year
# sex
# age
# suicides_no
# population
# suicides/100k pop
# country-year
# HDI for year
#  gdp_for_year ($)
# gdp_per_capita ($)
# generation

# %%
import pandas as pd

# Read the Excel file with the specified sheet name
sheet_name = 'master'
df = pd.read_excel('master1.xlsx', sheet_name=sheet_name)

# Define a dictionary mapping each country to its corresponding continent
continent_mapping = {
    'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
    'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
    'Bahrain': 'Asia', 'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe',
    'Belize': 'North America', 'Bosnia and Herzegovina': 'Europe', 'Brazil': 'South America',
    'Bulgaria': 'Europe', 'Canada': 'North America', 'Chile': 'South America', 'Colombia': 'South America',
    'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cuba': 'North America', 'Cyprus': 'Asia',
    'Czech Republic': 'Europe', 'Denmark': 'Europe', 'Ecuador': 'South America', 'El Salvador': 'North America',
    'Estonia': 'Europe', 'Fiji': 'Australia', 'Finland': 'Europe', 'France': 'Europe', 'Georgia': 'Asia',
    'Germany': 'Europe', 'Greece': 'Europe', 'Grenada': 'North America', 'Guatemala': 'North America',
    'Guyana': 'South America', 'Hungary': 'Europe', 'Iceland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe',
    'Jamaica': 'North America', 'Japan': 'Asia', 'Kazakhstan': 'Asia', 'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia', 'Latvia': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe',
    'Maldives': 'Asia', 'Malta': 'Europe', 'Mauritius': 'Africa', 'Mexico': 'North America',
    'Montenegro': 'Europe', 'Netherlands': 'Europe', 'New Zealand': 'Australia', 'Nicaragua': 'North America',
    'Norway': 'Europe', 'Oman': 'Asia', 'Panama': 'North America', 'Paraguay': 'South America',
    'Philippines': 'Asia', 'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Republic of Ireland': 'Europe',
    'Romania': 'Europe', 'Saint Lucia': 'North America', 'Saint Vincent and the Grenadines': 'North America',
    'Serbia': 'Europe', 'Seychelles': 'Africa', 'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe',
    'South Africa': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia', 'Suriname': 'South America',
    'Sweden': 'Europe', 'Switzerland': 'Europe', 'Thailand': 'Asia', 'The Bahamas': 'North America',
    'Trinidad and Tobago': 'North America', 'Turkmenistan': 'Asia', 'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia', 'United Kingdom': 'Europe', 'United States': 'North America',
    'Uruguay': 'South America', 'Uzbekistan': 'Asia'
}

# Add a new column 'Continent' based on the mapping
df['Continent'] = df['Country'].map(continent_mapping)

# Group by 'Continent' and aggregate the data
grouped_df = df.groupby(['Continent', 'year', 'sex', 'age']).agg({
    'suicides_no': 'sum',
    'population': 'sum',
    'suicides/100k pop': 'mean',
    'HDI for year': 'mean',
    ' gdp_for_year ($) ': 'sum',
    'gdp_per_capita ($)': 'mean'
}).reset_index()

# Output the grouped data to a new Excel file
grouped_df.to_excel('grouped_cabana.xlsx', index=False)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Read the Excel file with the specified sheet name
sheet_name = 'master'
df = pd.read_excel('master1.xlsx', sheet_name=sheet_name)

# Drop unnecessary columns
df.drop(['country-year', 'HDI for year'], axis=1, inplace=True)

# Check for missing values
missing_values = df.isnull().sum()
print("Missing Values:")
print(missing_values)

# Handle missing values (replace with mean, median, or drop rows/columns)
# For demonstration, let's drop rows with missing values
df.dropna(inplace=True)

# Encode categorical variables
label_encoder = LabelEncoder()
df['sex'] = label_encoder.fit_transform(df['sex'])
df['age'] = label_encoder.fit_transform(df['age'])
df['generation'] = label_encoder.fit_transform(df['generation'])

# Normalize numerical features
scaler = StandardScaler()
numerical_cols = ['suicides_no', 'population', 'suicides/100k pop', ' gdp_for_year ($) ', 'gdp_per_capita ($)']
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Group by 'Continent' and aggregate the data
continent_mapping = {
    'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
    'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
    'Bahrain': 'Asia', 'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe',
    'Belize': 'North America', 'Bosnia and Herzegovina': 'Europe', 'Brazil': 'South America',
    'Bulgaria': 'Europe', 'Canada': 'North America', 'Chile': 'South America', 'Colombia': 'South America',
    'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cuba': 'North America', 'Cyprus': 'Asia',
    'Czech Republic': 'Europe', 'Denmark': 'Europe', 'Ecuador': 'South America', 'El Salvador': 'North America',
    'Estonia': 'Europe', 'Fiji': 'Australia', 'Finland': 'Europe', 'France': 'Europe', 'Georgia': 'Asia',
    'Germany': 'Europe', 'Greece': 'Europe', 'Grenada': 'North America', 'Guatemala': 'North America',
    'Guyana': 'South America', 'Hungary': 'Europe', 'Iceland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe',
    'Jamaica': 'North America', 'Japan': 'Asia', 'Kazakhstan': 'Asia', 'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia', 'Latvia': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe',
    'Maldives': 'Asia', 'Malta': 'Europe', 'Mauritius': 'Africa', 'Mexico': 'North America',
    'Montenegro': 'Europe', 'Netherlands': 'Europe', 'New Zealand': 'Australia', 'Nicaragua': 'North America',
    'Norway': 'Europe', 'Oman': 'Asia', 'Panama': 'North America', 'Paraguay': 'South America',
    'Philippines': 'Asia', 'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Republic of Ireland': 'Europe',
    'Romania': 'Europe', 'Saint Lucia': 'North America', 'Saint Vincent and the Grenadines': 'North America',
    'Serbia': 'Europe', 'Seychelles': 'Africa', 'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe',
    'South Africa': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia', 'Suriname': 'South America',
    'Sweden': 'Europe', 'Switzerland': 'Europe', 'Thailand': 'Asia', 'The Bahamas': 'North America',
    'Trinidad and Tobago': 'North America', 'Turkmenistan': 'Asia', 'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia', 'United Kingdom': 'Europe', 'United States': 'North America',
    'Uruguay': 'South America', 'Uzbekistan': 'Asia'
}

# Add a new column 'Continent' based on the mapping
df['Continent'] = df['Country'].map(continent_mapping)

# Group by 'Continent' and aggregate the data
grouped_df = df.groupby(['Continent', 'year', 'sex', 'age']).agg({
    'suicides_no': 'sum',
    'population': 'sum',
    'suicides/100k pop': 'mean',
    ' gdp_for_year ($) ': 'sum',
    'gdp_per_capita ($)': 'mean'
}).reset_index()

# Output the grouped data to a new Excel file
grouped_df.to_excel('grouped_cabana.xlsx', index=False)
# Out:
# Missing Values:
# Country               6970
# year                     0
# sex                      0
# age                      0
# suicides_no              0
# population               0
# suicides/100k pop        0
#  gdp_for_year ($)        0
# gdp_per_capita ($)       0
# generation               0
# dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Read the Excel file with the specified sheet name
sheet_name = 'master'
df = pd.read_excel('master1.xlsx', sheet_name=sheet_name)

# Drop unnecessary columns
df.drop(['country-year', 'HDI for year'], axis=1, inplace=True)

# Check for missing values
missing_values = df.isnull().sum()
print("Missing Values:")
print(missing_values)

# Handle missing values if any
# For demonstration, let's fill missing numerical values with the mean and missing categorical values with mode
numerical_cols = ['suicides_no', 'population', 'suicides/100k pop', ' gdp_for_year ($) ', 'gdp_per_capita ($)']
categorical_cols = ['sex', 'age', 'generation']
df[numerical_cols] = df[numerical_cols].fillna(df[numerical_cols].mean())
df[categorical_cols] = df[categorical_cols].fillna(df[categorical_cols].mode().iloc[0])

# Encode categorical variables
label_encoder = LabelEncoder()
df['sex'] = label_encoder.fit_transform(df['sex'])
df['age'] = label_encoder.fit_transform(df['age'])
df['generation'] = label_encoder.fit_transform(df['generation'])

# Normalize numerical features
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Add a new column 'Continent' based on the mapping
continent_mapping = {
    'Albania': 'Europe', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America',
    'Armenia': 'Asia', 'Australia': 'Australia', 'Austria': 'Europe', 'Azerbaijan': 'Asia',
    'Bahrain': 'Asia', 'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe',
    'Belize': 'North America', 'Bosnia and Herzegovina': 'Europe', 'Brazil': 'South America',
    'Bulgaria': 'Europe', 'Canada': 'North America', 'Chile': 'South America', 'Colombia': 'South America',
    'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cuba': 'North America', 'Cyprus': 'Asia',
    'Czech Republic': 'Europe', 'Denmark': 'Europe', 'Ecuador': 'South America', 'El Salvador': 'North America',
    'Estonia': 'Europe', 'Fiji': 'Australia', 'Finland': 'Europe', 'France': 'Europe', 'Georgia': 'Asia',
    'Germany': 'Europe', 'Greece': 'Europe', 'Grenada': 'North America', 'Guatemala': 'North America',
    'Guyana': 'South America', 'Hungary': 'Europe', 'Iceland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe',
    'Jamaica': 'North America', 'Japan': 'Asia', 'Kazakhstan': 'Asia', 'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia', 'Latvia': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe',
    'Maldives': 'Asia', 'Malta': 'Europe', 'Mauritius': 'Africa', 'Mexico': 'North America',
    'Montenegro': 'Europe', 'Netherlands': 'Europe', 'New Zealand': 'Australia', 'Nicaragua': 'North America',
    'Norway': 'Europe', 'Oman': 'Asia', 'Panama': 'North America', 'Paraguay': 'South America',
    'Philippines': 'Asia', 'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Republic of Ireland': 'Europe',
    'Romania': 'Europe', 'Saint Lucia': 'North America', 'Saint Vincent and the Grenadines': 'North America',
    'Serbia': 'Europe', 'Seychelles': 'Africa', 'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe',
    'South Africa': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia', 'Suriname': 'South America',
    'Sweden': 'Europe', 'Switzerland': 'Europe', 'Thailand': 'Asia', 'The Bahamas': 'North America',
    'Trinidad and Tobago': 'North America', 'Turkmenistan': 'Asia', 'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia', 'United Kingdom': 'Europe', 'United States': 'North America',
    'Uruguay': 'South America', 'Uzbekistan': 'Asia'
}

df['Continent'] = df['Country'].map(continent_mapping)

# Group by 'Continent', 'year', 'sex', 'age' and aggregate the data
grouped_df = df.groupby(['Continent', 'year', 'sex', 'age']).agg({
    'suicides_no': 'sum',
    'population': 'sum',
    'suicides/100k pop': 'mean',
    ' gdp_for_year ($) ': 'sum',
    'gdp_per_capita ($)': 'mean'
}).reset_index()

# Output the grouped data to a new Excel file
grouped_df.to_excel('grouped_cabana.xlsx', index=False)
# Out:
# Missing Values:
# Country               6970
# year                     0
# sex                      0
# age                      0
# suicides_no              0
# population               0
# suicides/100k pop        0
#  gdp_for_year ($)        0
# gdp_per_capita ($)       0
# generation               0
# dtype: int64
# C:\Users\F8871976\AppData\Local\Temp\ipykernel_8432\255719548.py:21: UserWarning: Unable to sort modes: '<' not supported between instances of 'datetime.datetime' and 'str'
#   df[categorical_cols] = df[categorical_cols].fillna(df[categorical_cols].mode().iloc[0])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:173, in _unique_python(values, return_inverse, return_counts)
#     171 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 173 uniques = sorted(uniques_set)
# ...
